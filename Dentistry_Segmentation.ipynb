# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install ultralytics

# %%
# !yolo task=segment mode=train data='/content/gdrive/MyDrive/Dentistry.v1i.yolov8/data.yaml' model=yolov8n.pt epochs=50 lr0=0.01
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 111MB/s]
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Dentistry.v1i.yolov8'

# %%
# !yolo task=segment mode=predict model='/content/gdrive/MyDrive/Dentistry.v1i.yolov8/runs/detect/train/weights/best.pt' source='/content/gdrive/MyDrive/xray.jpeg' save=True show_conf=False
# Out:
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3012473 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/gdrive/MyDrive/xray.jpeg: 608x640 2 11s, 2 12s, 2 13s, 1 16, 1 17, 1 18, 3 21s, 1 23, 1 25, 2 26s, 1 31, 2 35s, 1 37, 1 41, 1 42, 1 43, 2 45s, 2 46s, 2 47s, 101.6ms
# Speed: 6.6ms preprocess, 101.6ms inference, 786.5ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install google-colab

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread('/content/runs/detect/predict/xray.jpeg')
img = cv2.resize(img, (350, 350))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350>

# %%
# !yolo task=segment mode=predict model='/content/gdrive/MyDrive/Dentistry.v1i.yolov8/runs/detect/train/weights/best.pt' source='/content/download (2).jpeg' save=True show_conf=False
# Out:
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3012473 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/download (2).jpeg: 352x640 1 16, 2 21s, 1 22, 1 26, 2 33s, 2 34s, 2 35s, 3 36s, 1 37, 1 43, 1 46, 1 47, 52 Crowns, 7 Root Canals, 109.3ms
# Speed: 2.9ms preprocess, 109.3ms inference, 475.7ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
img = cv2.imread('/content/runs/detect/predict2/download (2).jpeg')
img = cv2.resize(img, (550, 350))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=550x350>

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Dentistry.v1i.yolov8/output'
